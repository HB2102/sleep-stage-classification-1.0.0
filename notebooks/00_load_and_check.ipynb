# %%
import os

print(os.path.exists('../data/raw/SC4001E0-PSG.edf'))  
print(os.path.exists('../data/raw/SC4001EC-Hypnogram.edf'))
# Out:
# True
# True

# %%
import mne
raw = mne.io.read_raw_edf('../data/raw/SC4001E0-PSG.edf', preload=True)
print(raw.ch_names)
# Out:
# Extracting EDF parameters from d:\UNI\پروژه پایانی\Sleep Stage Project 1.0\data\raw\SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7949999  =      0.000 ... 79499.990 secs...
# C:\Users\Hossein\AppData\Local\Temp\ipykernel_26248\1362382988.py:2: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf('../data/raw/SC4001E0-PSG.edf', preload=True)
# C:\Users\Hossein\AppData\Local\Temp\ipykernel_26248\1362382988.py:2: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf('../data/raw/SC4001E0-PSG.edf', preload=True)
# C:\Users\Hossein\AppData\Local\Temp\ipykernel_26248\1362382988.py:2: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
# ...

# %%
import sys
sys.path.append("../utils")

from reader import read_record

raw, events = read_record(
    '../data/raw/SC4001E0-PSG.edf',
    '../data/raw/SC4001EC-Hypnogram.edf',
    channel='EEG Fpz-Cz'
)
raw.plot(duration=60, scalings='auto')  
print(events[:5])
# Out:
# Extracting EDF parameters from d:\UNI\پروژه پایانی\Sleep Stage Project 1.0\data\raw\SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7949999  =      0.000 ... 79499.990 secs...
# d:\UNI\پروژه پایانی\Sleep Stage Project 1.0\notebooks\../utils\reader.py:17: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(psg_path, preload=True)
# d:\UNI\پروژه پایانی\Sleep Stage Project 1.0\notebooks\../utils\reader.py:17: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(psg_path, preload=True)
# d:\UNI\پروژه پایانی\Sleep Stage Project 1.0\notebooks\../utils\reader.py:17: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(psg_path, preload=True)
# ...
